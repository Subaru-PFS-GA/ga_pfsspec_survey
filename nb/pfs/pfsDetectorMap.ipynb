# %%
DATA_FILE = '/datascope/subaru/data/ssp/S25A-OT02/2d/S25A_April2026/detectorMap/20250403/123533/detectorMap_PFS_123533_m1_S25A_April2026.fits'

# %%
from astropy.io import fits
from pfs.drp.stella import DetectorMap

# %%
with fits.open(DATA_FILE) as hdul:
    dm = DetectorMap.fromFits(hdul)

# %%
dm

# %%
hdul.info()
