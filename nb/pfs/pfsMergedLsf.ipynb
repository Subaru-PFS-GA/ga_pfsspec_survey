# %%
import sys
import pickle

# %%
sys.path.insert(0, '/home/dobos/project/Subaru-PFS/drp_stella/python')

# %%
fn = '/datascope/subaru/data/commissioning/rerun/20241127a/20241204T232611Z/pfsMergedLsf/20240529/111009/pfsMergedLsf_PFS_111009_u_kiyoyabe_processing_20241127a_20241204T232611Z.pickle'
pickle.load(open(fn, 'rb'))
